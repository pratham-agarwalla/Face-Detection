# %%
import cv2

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start the video capture
video_capture = cv2.VideoCapture(0)

while True:
    # Read a frame from the video
    ret, frame = video_capture.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale frame
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )

    # Draw rectangles around the detected faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Display the resulting frame
    cv2.imshow('Video', frame)

    # Exit the loop if the user presses 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
video_capture.release()

# Close all windows
cv2.destroyAllWindows()
# Out:
# 1   HIToolbox                           0x00007ff80b28a52b _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 259
# 2   HIToolbox                           0x00007ff80b18333e _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 34
# 3   HIToolbox                           0x00007ff80b1832b3 _ZN15MenuBarInstance14EnableAutoShowEv + 47
# 4   HIToolbox                           0x00007ff80b127908 SetMenuBarObscured + 408
# 5   HIToolbox                           0x00007ff80b1274ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 6   HIToolbox                           0x00007ff80b121996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 7   HIToolbox                           0x00007ff80b0e9bd2 _NotifyEventLoopObservers + 153
# 8   HIToolbox                           0x00007ff80b1213e6 AcquireEventFromQueue + 494
# 9   HIToolbox                           0x00007ff80b1103ec ReceiveNextEventCommon + 285
# 10  HIToolbox                           0x00007ff80b1102b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 11  AppKit                              0x00007ff8043092f3 _DPSNextEvent + 909
# 12  AppKit                              0x00007ff804308174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 13  cv2.abi3.so                         0x000000013245c12c cvWaitKey + 348
# 14  cv2.abi3.so                         0x0000000132455a06 _ZN2cv9waitKeyExEi + 198
# 15  cv2.abi3.so                         0x0000000132455b14 _ZN2cv7waitKeyEi + 36
# 16  cv2.abi3.so                         0x00000001315f7e34 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 17  python3.9                           0x0000000102809da4 cfunction_call + 52
# 18  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 19  python3.9                           0x00000001028dbee7 call_function + 311
# 20  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 21  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 22  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 23  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 24  python3.9                           0x00000001028dbe5e call_function + 174
# 25  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 26  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 27  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 28  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 29  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 30  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 31  python3.9                           0x00000001027bc967 method_vectorcall_O + 103
# 32  python3.9                           0x00000001028dbe5e call_function + 174
# 33  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 34  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 35  python3.9                           0x00000001028dbe5e call_function + 174
# 36  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 37  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 38  python3.9                           0x00000001028dbe5e call_function + 174
# 39  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 40  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 41  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 42  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 43  python3.9                           0x00000001027ae783 PyVectorcall_Call + 163
# 44  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 45  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 46  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 47  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 48  python3.9                           0x00000001028dbe5e call_function + 174
# 49  python3.9                           0x00000001028cf252 _PyEval_EvalFrameDefault + 4482
# 50  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 51  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 52  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 53  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 54  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 55  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 56  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 57  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 58  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 59  _asyncio.cpython-39-darwin.so       0x000000010bfe697a task_step_impl + 442
# 60  _asyncio.cpython-39-darwin.so       0x000000010bfe672e task_step + 62
# 61  _asyncio.cpython-39-darwin.so       0x000000010bfe65c8 task_wakeup + 104
# 62  _asyncio.cpython-39-darwin.so       0x000000010bfe64bd TaskWakeupMethWrapper_call + 109
# 63  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 64  python3.9                           0x00000001028f7641 context_run + 81
# 65  python3.9                           0x000000010280a68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 66  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 67  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 68  python3.9                           0x00000001028dbe5e call_function + 174
# 69  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 70  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 71  python3.9                           0x00000001028dbe5e call_function + 174
# 72  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 73  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 74  python3.9                           0x00000001028dbe5e call_function + 174
# 75  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 76  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 77  python3.9                           0x00000001028dbe5e call_function + 174
# 78  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 79  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 80  python3.9                           0x00000001028dbe5e call_function + 174
# 81  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 82  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 83  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 84  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 85  python3.9                           0x00000001028dbe5e call_function + 174
# 86  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 87  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 88  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 89  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 90  python3.9                           0x00000001028dbe5e call_function + 174
# 91  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 92  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 93  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 94  python3.9                           0x00000001028dbe5e call_function + 174
# 95  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 96  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 97  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 98  python3.9                           0x0000000102960142 pymain_run_module + 258
# 99  python3.9                           0x000000010295fa01 pymain_run_python + 241
# 100 python3.9                           0x000000010295f8c5 Py_RunMain + 37
# 101 python3.9                           0x0000000102960f90 pymain_main + 64
# 102 python3.9                           0x0000000102745408 main + 56
# 103 dyld                                0x0000000202d47310 start + 2432
# 1   HIToolbox                           0x00007ff80b28a52b _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 259
# 2   HIToolbox                           0x00007ff80b18333e _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 34
# 3   HIToolbox                           0x00007ff80b186ec6 _ZL19AutoShowHideHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 83
# 4   HIToolbox                           0x00007ff80b0ea48d _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 1381
# 5   HIToolbox                           0x00007ff80b0e98cc _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 333
# 6   HIToolbox                           0x00007ff80b0e9773 SendEventToEventTargetWithOptions + 45
# 7   HIToolbox                           0x00007ff80b128229 _ZL29ToolboxEventDispatcherHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 1312
# 8   HIToolbox                           0x00007ff80b0ea936 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 2574
# 9   HIToolbox                           0x00007ff80b0e98cc _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 333
# 10  HIToolbox                           0x00007ff80b0fe529 SendEventToEventTarget + 39
# 11  AppKit                              0x00007ff80430870d -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 2652
# 12  cv2.abi3.so                         0x000000013245c12c cvWaitKey + 348
# 13  cv2.abi3.so                         0x0000000132455a06 _ZN2cv9waitKeyExEi + 198
# 14  cv2.abi3.so                         0x0000000132455b14 _ZN2cv7waitKeyEi + 36
# 15  cv2.abi3.so                         0x00000001315f7e34 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.9                           0x0000000102809da4 cfunction_call + 52
# 17  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 18  python3.9                           0x00000001028dbee7 call_function + 311
# 19  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 20  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 21  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 22  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 23  python3.9                           0x00000001028dbe5e call_function + 174
# 24  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 25  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 26  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 27  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 28  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 29  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 30  python3.9                           0x00000001027bc967 method_vectorcall_O + 103
# 31  python3.9                           0x00000001028dbe5e call_function + 174
# 32  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 33  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 34  python3.9                           0x00000001028dbe5e call_function + 174
# 35  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 36  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 37  python3.9                           0x00000001028dbe5e call_function + 174
# 38  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 39  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 40  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 41  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 42  python3.9                           0x00000001027ae783 PyVectorcall_Call + 163
# 43  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 44  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 45  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 46  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 47  python3.9                           0x00000001028dbe5e call_function + 174
# 48  python3.9                           0x00000001028cf252 _PyEval_EvalFrameDefault + 4482
# 49  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 50  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 52  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 53  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 54  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 55  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 56  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 57  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 58  _asyncio.cpython-39-darwin.so       0x000000010bfe697a task_step_impl + 442
# 59  _asyncio.cpython-39-darwin.so       0x000000010bfe672e task_step + 62
# 60  _asyncio.cpython-39-darwin.so       0x000000010bfe65c8 task_wakeup + 104
# 61  _asyncio.cpython-39-darwin.so       0x000000010bfe64bd TaskWakeupMethWrapper_call + 109
# 62  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 63  python3.9                           0x00000001028f7641 context_run + 81
# 64  python3.9                           0x000000010280a68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 65  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 66  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 67  python3.9                           0x00000001028dbe5e call_function + 174
# 68  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 69  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 70  python3.9                           0x00000001028dbe5e call_function + 174
# 71  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 72  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 73  python3.9                           0x00000001028dbe5e call_function + 174
# 74  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 75  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 76  python3.9                           0x00000001028dbe5e call_function + 174
# 77  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 78  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 79  python3.9                           0x00000001028dbe5e call_function + 174
# 80  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 81  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 82  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 83  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 84  python3.9                           0x00000001028dbe5e call_function + 174
# 85  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 86  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 87  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 88  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 89  python3.9                           0x00000001028dbe5e call_function + 174
# 90  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 91  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 92  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 93  python3.9                           0x00000001028dbe5e call_function + 174
# 94  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 95  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 96  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 97  python3.9                           0x0000000102960142 pymain_run_module + 258
# 98  python3.9                           0x000000010295fa01 pymain_run_python + 241
# 99  python3.9                           0x000000010295f8c5 Py_RunMain + 37
# 100 python3.9                           0x0000000102960f90 pymain_main + 64
# 101 python3.9                           0x0000000102745408 main + 56
# 102 dyld                                0x0000000202d47310 start + 2432
# 1   HIToolbox                           0x00007ff80b183726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff80b14c638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff805de723d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff805de57f3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff8060f4686 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff805f10aec SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff80b11d156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff80b11d0fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff8012ad18c __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff8012803f8 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff801280337 __CFRunLoopDoSource1 + 536
# 12  CoreFoundation                      0x00007ff80127efb6 __CFRunLoopRun + 2749
# 13  CoreFoundation                      0x00007ff80127de7f CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff80b110766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff80b110576 ReceiveNextEventCommon + 679
# 16  HIToolbox                           0x00007ff80b1102b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff8043092f3 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff804308174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.abi3.so                         0x000000013245c12c cvWaitKey + 348
# 20  cv2.abi3.so                         0x0000000132455a06 _ZN2cv9waitKeyExEi + 198
# 21  cv2.abi3.so                         0x0000000132455b14 _ZN2cv7waitKeyEi + 36
# 22  cv2.abi3.so                         0x00000001315f7e34 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.9                           0x0000000102809da4 cfunction_call + 52
# 24  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 25  python3.9                           0x00000001028dbee7 call_function + 311
# 26  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 27  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 28  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 29  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 30  python3.9                           0x00000001028dbe5e call_function + 174
# 31  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 32  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 33  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 34  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 35  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 36  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 37  python3.9                           0x00000001027bc967 method_vectorcall_O + 103
# 38  python3.9                           0x00000001028dbe5e call_function + 174
# 39  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 40  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 41  python3.9                           0x00000001028dbe5e call_function + 174
# 42  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 43  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 44  python3.9                           0x00000001028dbe5e call_function + 174
# 45  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 46  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 47  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 48  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 49  python3.9                           0x00000001027ae783 PyVectorcall_Call + 163
# 50  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 51  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 52  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 53  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 54  python3.9                           0x00000001028dbe5e call_function + 174
# 55  python3.9                           0x00000001028cf252 _PyEval_EvalFrameDefault + 4482
# 56  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 57  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 58  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 59  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 60  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 61  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 62  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 63  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 64  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 65  _asyncio.cpython-39-darwin.so       0x000000010bfe697a task_step_impl + 442
# 66  _asyncio.cpython-39-darwin.so       0x000000010bfe672e task_step + 62
# 67  _asyncio.cpython-39-darwin.so       0x000000010bfe65c8 task_wakeup + 104
# 68  _asyncio.cpython-39-darwin.so       0x000000010bfe64bd TaskWakeupMethWrapper_call + 109
# 69  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 70  python3.9                           0x00000001028f7641 context_run + 81
# 71  python3.9                           0x000000010280a68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 72  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 73  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 74  python3.9                           0x00000001028dbe5e call_function + 174
# 75  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 76  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 77  python3.9                           0x00000001028dbe5e call_function + 174
# 78  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 79  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 80  python3.9                           0x00000001028dbe5e call_function + 174
# 81  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 82  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 83  python3.9                           0x00000001028dbe5e call_function + 174
# 84  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 85  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 86  python3.9                           0x00000001028dbe5e call_function + 174
# 87  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 88  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 89  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 90  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 91  python3.9                           0x00000001028dbe5e call_function + 174
# 92  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 93  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 94  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 95  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 96  python3.9                           0x00000001028dbe5e call_function + 174
# 97  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 98  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 99  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 100 python3.9                           0x00000001028dbe5e call_function + 174
# 101 python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 102 python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 103 python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 104 python3.9                           0x0000000102960142 pymain_run_module + 258
# 105 python3.9                           0x000000010295fa01 pymain_run_python + 241
# 106 python3.9                           0x000000010295f8c5 Py_RunMain + 37
# 107 python3.9                           0x0000000102960f90 pymain_main + 64
# 108 python3.9                           0x0000000102745408 main + 56
# 109 dyld                                0x0000000202d47310 start + 2432
# 1   HIToolbox                           0x00007ff80b1100c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff80b1277e3 SetMenuBarObscured + 115
# 3   HIToolbox                           0x00007ff80b12e29e _ZN13HIApplication11FrontUILostEv + 34
# 4   HIToolbox                           0x00007ff80b127622 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 508
# 5   HIToolbox                           0x00007ff80b121950 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 182
# 6   HIToolbox                           0x00007ff80b0e9bd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff80b1213e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff80b1103ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff80b1102b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff8043092f3 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff804308174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  cv2.abi3.so                         0x000000013245c12c cvWaitKey + 348
# 13  cv2.abi3.so                         0x0000000132455a06 _ZN2cv9waitKeyExEi + 198
# 14  cv2.abi3.so                         0x0000000132455b14 _ZN2cv7waitKeyEi + 36
# 15  cv2.abi3.so                         0x00000001315f7e34 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.9                           0x0000000102809da4 cfunction_call + 52
# 17  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 18  python3.9                           0x00000001028dbee7 call_function + 311
# 19  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 20  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 21  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 22  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 23  python3.9                           0x00000001028dbe5e call_function + 174
# 24  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 25  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 26  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 27  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 28  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 29  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 30  python3.9                           0x00000001027bc967 method_vectorcall_O + 103
# 31  python3.9                           0x00000001028dbe5e call_function + 174
# 32  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 33  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 34  python3.9                           0x00000001028dbe5e call_function + 174
# 35  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 36  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 37  python3.9                           0x00000001028dbe5e call_function + 174
# 38  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 39  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 40  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 41  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 42  python3.9                           0x00000001027ae783 PyVectorcall_Call + 163
# 43  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 44  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 45  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 46  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 47  python3.9                           0x00000001028dbe5e call_function + 174
# 48  python3.9                           0x00000001028cf252 _PyEval_EvalFrameDefault + 4482
# 49  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 50  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 52  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 53  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 54  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 55  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 56  python3.9                           0x00000001028d6013 _PyEval_EvalFrameDefault + 32579
# 57  python3.9                           0x00000001027c7ccf gen_send_ex + 175
# 58  _asyncio.cpython-39-darwin.so       0x000000010bfe697a task_step_impl + 442
# 59  _asyncio.cpython-39-darwin.so       0x000000010bfe672e task_step + 62
# 60  _asyncio.cpython-39-darwin.so       0x000000010bfe65c8 task_wakeup + 104
# 61  _asyncio.cpython-39-darwin.so       0x000000010bfe64bd TaskWakeupMethWrapper_call + 109
# 62  python3.9                           0x00000001027ade86 _PyObject_MakeTpCall + 134
# 63  python3.9                           0x00000001028f7641 context_run + 81
# 64  python3.9                           0x000000010280a68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 65  python3.9                           0x00000001028d37d6 _PyEval_EvalFrameDefault + 22278
# 66  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 67  python3.9                           0x00000001028dbe5e call_function + 174
# 68  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 69  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 70  python3.9                           0x00000001028dbe5e call_function + 174
# 71  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 72  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 73  python3.9                           0x00000001028dbe5e call_function + 174
# 74  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 75  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 76  python3.9                           0x00000001028dbe5e call_function + 174
# 77  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 78  python3.9                           0x00000001027aebcb function_code_fastcall + 139
# 79  python3.9                           0x00000001028dbe5e call_function + 174
# 80  python3.9                           0x00000001028d38fa _PyEval_EvalFrameDefault + 22570
# 81  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 82  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 83  python3.9                           0x00000001027b1e2e method_vectorcall + 158
# 84  python3.9                           0x00000001028dbe5e call_function + 174
# 85  python3.9                           0x00000001028d4c51 _PyEval_EvalFrameDefault + 27521
# 86  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 87  python3.9                           0x00000001028c6f09 builtin_exec + 377
# 88  python3.9                           0x000000010280a755 cfunction_vectorcall_FASTCALL + 85
# 89  python3.9                           0x00000001028dbe5e call_function + 174
# 90  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 91  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 92  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 93  python3.9                           0x00000001028dbe5e call_function + 174
# 94  python3.9                           0x00000001028d3f3d _PyEval_EvalFrameDefault + 24173
# 95  python3.9                           0x00000001028cca09 _PyEval_EvalCode + 489
# 96  python3.9                           0x00000001027aeb0c _PyFunction_Vectorcall + 236
# 97  python3.9                           0x0000000102960142 pymain_run_module + 258
# 98  python3.9                           0x000000010295fa01 pymain_run_python + 241
# 99  python3.9                           0x000000010295f8c5 Py_RunMain + 37
# 100 python3.9                           0x0000000102960f90 pymain_main + 64
# 101 python3.9                           0x0000000102745408 main + 56
# 102 dyld                                0x0000000202d47310 start + 2432
